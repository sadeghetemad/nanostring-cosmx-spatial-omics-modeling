# %%
import pandas as pd

# %%
moran_df = pd.read_csv('data/All_MoranI_combined.csv')
moran_df
# Out:
#                                                    Task         I  \
# 0                                     Vesicle secretion  0.124935
# 1          Trafficking to endosomes (Clathrin Vesicles)  0.124935
# 2                                  Elaidate degradation  0.088321
# 3                                 Palmitate degradation  0.088321
# 4                                Linolenate degradation  0.087585
# ...                                                 ...       ...
# 2194  Synthesis of estradiol-17beta (E2) from andros...  0.024255
# 2195     Synthesis of estrone (E1) from androstenedione  0.014400
# 2196  Keratan sulfate biosynthesis from O-glycan (co...  0.005509
# 2197  Keratan sulfate biosynthesis from O-glycan (co...  0.005509
# 2198         Keratan sulfate biosynthesis from N-glycan  0.005509
#
#          pval_norm  var_norm  pval_norm_fdr_bh Subject_ID Treatment_Status
# 0     1.749904e-08  0.000529      8.749521e-07   1182412B          Treated
# ...

# %%
mt_treated = pd.read_csv('data/Metabolic_Tasks_Treated.csv')
mt_treated
# Out:
# /tmp/ipykernel_25701/3191822260.py:1: DtypeWarning: Columns (100) have mixed types. Specify dtype option on import or set low_memory=False.
#   mt_treated = pd.read_csv('data/Metabolic_Tasks_Treated.csv')
#        (R)-3-Hydroxybutanoate synthesis  \
# 0                             16.305230
# 1                             10.107167
# 2                             24.595199
# 3                             19.672966
# 4                             23.447574
# ...                                 ...
# 69211                         26.734473
# 69212                         26.146413
# 69213                         23.304742
# 69214                         22.844434
# 69215                         27.941969
#
#        ATP generation from glucose (hypoxic conditions) - glycolysis  \
# 0                                              16.305230
# 1                                              10.107167
# 2                                              24.595199
# ...

# %%
mt_untreated = pd.read_csv('Metabolic_Tasks_Untreated.csv')
mt_untreated
# Out:
#         (R)-3-Hydroxybutanoate synthesis  \
# 0                              21.830919
# 1                              24.044764
# 2                              25.354333
# 3                              23.603235
# 4                              24.257634
# ...                                  ...
# 105526                         21.142798
# 105527                         19.619905
# 105528                         17.752364
# 105529                          1.663116
# 105530                         17.915117
#
#         ATP generation from glucose (hypoxic conditions) - glycolysis  \
# 0                                               21.830919
# 1                                               24.044764
# 2                                               25.354333
# 3                                               23.603235
# 4                                               24.257634
# ...                                                   ...
# ...
